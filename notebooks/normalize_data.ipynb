# %%
import pandas as pd
import re

# %%
# Load your DataFrame
df = pd.read_csv(r'C:\Users\Admin.DESKTOP-M4R2VLU\week7\data\CheMed123.csv', delimiter=',', on_bad_lines='skip')

# %%
df
# Out:
#    Channel Title Channel Username  ID  \
# 0         CheMed       @CheMed123  97
# 1         CheMed       @CheMed123  96
# 2         CheMed       @CheMed123  95
# 3         CheMed       @CheMed123  94
# 4         CheMed       @CheMed123  93
# ..           ...              ...  ..
# 71        CheMed       @CheMed123   6
# 72        CheMed       @CheMed123   4
# 73        CheMed       @CheMed123   3
# 74        CheMed       @CheMed123   2
# 75        CheMed       @CheMed123   1
#
#                                               Message  \
# 0   ⚠️Notice!\nDear esteemed customers,\nDue to fo...
# 1   Mela-One በውስጡ ሆርሞን ያለው ድንገተኛ ወሊድ መቆጣጠርያ ሲሆን ያለ...
# 2   አዚትሮማይሲን በሃኪም መድሃኒት ማዘዣ ከሚታዘዙ አንቲባዮቲኮች አንዱ ሲሆን...
# 3   Che-Med Trivia #3\n\nምግብና መጠጦች አንዳንድ መድሃኒቶች በደ...
# 4   Che-Med Trivia #2\n\nእንደ Ciprofloxacin, Doxycy...
# ..                                                ...
# 71                                                NaN
# 72                                                NaN
# ...

# %%
print("Checking for NaN values in the 'Message' column:")
nan_count = df['Message'].isnull().sum()
print(f"Number of NaN values in 'Message' column: {nan_count}")
# Out:
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 13

# %%
df = df.dropna(subset=['Message'])

# Print the shape of the dataset after dropping NaN values in the "Message" column
print(f"Dataset shape after dropping NaN values in 'Message' column: {df.shape}")
# Out:
# Dataset shape after dropping NaN values in 'Message' column: (63, 6)

# %%
df
# Out:
#    Channel Title Channel Username  ID  \
# 0         CheMed       @CheMed123  97
# 1         CheMed       @CheMed123  96
# 2         CheMed       @CheMed123  95
# 3         CheMed       @CheMed123  94
# 4         CheMed       @CheMed123  93
# ..           ...              ...  ..
# 66        CheMed       @CheMed123  13
# 67        CheMed       @CheMed123  11
# 68        CheMed       @CheMed123  10
# 69        CheMed       @CheMed123   9
# 74        CheMed       @CheMed123   2
#
#                                               Message  \
# 0   ⚠️Notice!\nDear esteemed customers,\nDue to fo...
# 1   Mela-One በውስጡ ሆርሞን ያለው ድንገተኛ ወሊድ መቆጣጠርያ ሲሆን ያለ...
# 2   አዚትሮማይሲን በሃኪም መድሃኒት ማዘዣ ከሚታዘዙ አንቲባዮቲኮች አንዱ ሲሆን...
# 3   Che-Med Trivia #3\n\nምግብና መጠጦች አንዳንድ መድሃኒቶች በደ...
# 4   Che-Med Trivia #2\n\nእንደ Ciprofloxacin, Doxycy...
# ..                                                ...
# 66  Say goodbye to the hustle of trying to find me...
# 67  🌼🌼🌼 መልካም አዲስ ዓመት 🌼🌼🌼\n\nየምስራች!! በአዲሱ አመት አዲስ ነ...
# ...

# %%
# Define a function to remove emojis
def remove_emojis(text):
    emoji_pattern = re.compile(
        "[" 
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F700-\U0001F77F"  # alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U00002702-\U000027B0"  # Dingbats
        "\U000024C2-\U0001F251" 
        "]+", 
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

# Apply the function to the 'Message' column
df['Message'] = df['Message'].apply(remove_emojis)

# Display the updated DataFrame
print(df.head())
# Out:
#   Channel Title Channel Username  ID  \
# 0        CheMed       @CheMed123  97
# 1        CheMed       @CheMed123  96
# 2        CheMed       @CheMed123  95
# 3        CheMed       @CheMed123  94
# 4        CheMed       @CheMed123  93
#
#                                              Message  \
# 0  Notice!\nDear esteemed customers,\nDue to four...
# 1  Mela-One በውስጡ ሆርሞን ያለው ድንገተኛ ወሊድ መቆጣጠርያ ሲሆን ያለ...
# 2  አዚትሮማይሲን በሃኪም መድሃኒት ማዘዣ ከሚታዘዙ አንቲባዮቲኮች አንዱ ሲሆን...
# 3  Che-Med Trivia #3\n\nምግብና መጠጦች አንዳንድ መድሃኒቶች በደ...
# 4  Che-Med Trivia #2\n\nእንደ Ciprofloxacin, Doxycy...
#
#                         Date                Media Path
# 0  2023-02-10 12:23:06+00:00  photos\@CheMed123_97.jpg
# 1  2023-02-02 08:58:52+00:00  photos\@CheMed123_96.jpg
# 2  2023-02-01 08:59:37+00:00  photos\@CheMed123_95.jpg
# 3  2023-01-31 09:19:53+00:00  photos\@CheMed123_94.jpg
# 4  2023-01-30 09:45:25+00:00  photos\@CheMed123_93.jpg
# ...

# %%
df
# Out:
#    Channel Title Channel Username  ID  \
# 0         CheMed       @CheMed123  97
# 1         CheMed       @CheMed123  96
# 2         CheMed       @CheMed123  95
# 3         CheMed       @CheMed123  94
# 4         CheMed       @CheMed123  93
# ..           ...              ...  ..
# 66        CheMed       @CheMed123  13
# 67        CheMed       @CheMed123  11
# 68        CheMed       @CheMed123  10
# 69        CheMed       @CheMed123   9
# 74        CheMed       @CheMed123   2
#
#                                               Message  \
# 0   Notice!\nDear esteemed customers,\nDue to four...
# 1   Mela-One በውስጡ ሆርሞን ያለው ድንገተኛ ወሊድ መቆጣጠርያ ሲሆን ያለ...
# 2   አዚትሮማይሲን በሃኪም መድሃኒት ማዘዣ ከሚታዘዙ አንቲባዮቲኮች አንዱ ሲሆን...
# 3   Che-Med Trivia #3\n\nምግብና መጠጦች አንዳንድ መድሃኒቶች በደ...
# 4   Che-Med Trivia #2\n\nእንደ Ciprofloxacin, Doxycy...
# ..                                                ...
# 66  Say goodbye to the hustle of trying to find me...
# 67   መልካም አዲስ ዓመት \n\nየምስራች!! በአዲሱ አመት አዲስ ነገር ለጤና...
# ...

# %%
df.to_csv(r'C:\Users\Admin.DESKTOP-M4R2VLU\week7\data\clean_CheMed123.csv')

# %%
import glob

# Use glob to create a list of all CSV files in the directory
all_files = glob.glob(r'C:\Users\Admin.DESKTOP-M4R2VLU\week7\data\clean_data\*.csv')

# Read and merge the CSV files
df = [pd.read_csv(f) for f in all_files]
merged_df = pd.concat(df, ignore_index=True)

# Save the merged DataFrame to a new CSV file
merged_df.to_csv(r'C:\Users\Admin.DESKTOP-M4R2VLU\week7\data\clean_data\merged_file.csv', index=False)

# %%
merged_df.head()
# Out:
#    Unnamed: 0 Channel Title Channel Username  ID  \
# 0           0        CheMed       @CheMed123  97
# 1           1        CheMed       @CheMed123  96
# 2           2        CheMed       @CheMed123  95
# 3           3        CheMed       @CheMed123  94
# 4           4        CheMed       @CheMed123  93
#
#                                              Message  \
# 0  Notice!\nDear esteemed customers,\nDue to four...
# 1  Mela-One በውስጡ ሆርሞን ያለው ድንገተኛ ወሊድ መቆጣጠርያ ሲሆን ያለ...
# 2  አዚትሮማይሲን በሃኪም መድሃኒት ማዘዣ ከሚታዘዙ አንቲባዮቲኮች አንዱ ሲሆን...
# 3  Che-Med Trivia #3\n\nምግብና መጠጦች አንዳንድ መድሃኒቶች በደ...
# 4  Che-Med Trivia #2\n\nእንደ Ciprofloxacin, Doxycy...
#
#                         Date                Media Path
# 0  2023-02-10 12:23:06+00:00  photos\@CheMed123_97.jpg
# 1  2023-02-02 08:58:52+00:00  photos\@CheMed123_96.jpg
# 2  2023-02-01 08:59:37+00:00  photos\@CheMed123_95.jpg
# 3  2023-01-31 09:19:53+00:00  photos\@CheMed123_94.jpg
# 4  2023-01-30 09:45:25+00:00  photos\@CheMed123_93.jpg

# %%
from sqlalchemy import create_engine

# Create an engine to connect to the PostgreSQL database
engine = create_engine('postgresql+psycopg2://postgres:jack@localhost:5432/Ethio_Medical')
#engine = create_engine('postgresql+psycopg2://postgres:jack@host:80/Ethio_medical')

# Save the DataFrame to the PostgreSQL database
merged_df.to_sql('medical_tbl', engine, if_exists='replace', index=False)
# Out:
# 350
