# %%
import pandas as pd
import re

# %%
# Load your DataFrame
df = pd.read_csv(r'C:\Users\Admin.DESKTOP-M4R2VLU\week7\data\EAHCI.csv', delimiter=',', on_bad_lines='skip')

# %%
df
# Out:
#                                          Channel Title Channel Username    ID  \
# 0    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2399
# 1    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2397
# 2    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2396
# 3    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2395
# 4    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2394
# ..                                                 ...              ...   ...
# 846  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1456
# 847  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1455
# 848  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1454
# 849  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1453
# 850  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1452
#
# ...

# %%
print("Checking for NaN values in the 'Message' column:")
nan_count = df['Message'].isnull().sum()
print(f"Number of NaN values in 'Message' column: {nan_count}")
# Out:
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 175

# %%
df = df.dropna(subset=['Message'])

# Print the shape of the dataset after dropping NaN values in the "Message" column
print(f"Dataset shape after dropping NaN values in 'Message' column: {df.shape}")
# Out:
# Dataset shape after dropping NaN values in 'Message' column: (676, 6)

# %%
df
# Out:
#                                          Channel Title Channel Username    ID  \
# 0    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2399
# 2    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2396
# 3    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2395
# 5    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2393
# 6    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2392
# ..                                                 ...              ...   ...
# 845  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1457
# 846  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1456
# 847  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1455
# 849  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1453
# 850  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1452
#
# ...

# %%
# Define a function to remove emojis
def remove_emojis(text):
    emoji_pattern = re.compile(
        "[" 
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F700-\U0001F77F"  # alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U00002702-\U000027B0"  # Dingbats
        "\U0001F1E0-\U0001F1FF"   # flag
        "\U000024C2-\U0001F251" 
        "]+", 
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

# Apply the function to the 'Message' column
df['Message'] = df['Message'].apply(remove_emojis)

# Display the updated DataFrame
print(df.head())
# Out:
#                                        Channel Title Channel Username    ID  \
# 0  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2399
# 2  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2396
# 3  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2395
# 5  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2393
# 6  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2392
#
#                                              Message  \
# 0   እሁድ ይጀምራል እንዳያመልጥዎ \n#Obstetric_Ultrasound_Tr...
# 2  ዛሬ ይጀምራል\n#የሞያ ፈቃድ በቅርቡ ለምታሳድሱ               \...
# 3  \n#የሞያ ፈቃድ በቅርቡ ለምታሳድሱ               \n\n#CPD_...
# 5  #Basic_Abdominal_Ultrasound_Training @#Hawassa...
# 6   እሁድ ይጀምራል እንዳያመልጥዎ \n#Obstetric_Ultrasound_Tr...
#
#                         Date              Media Path
# 0  2024-10-11 15:32:14+00:00  photos\@EAHCI_2399.jpg
# 2  2024-10-10 13:40:09+00:00  photos\@EAHCI_2396.jpg
# ...

# %%
# Remove # from all string entries in a specific column (e.g., 'column_name')
df['Message'] = df['Message'].replace('#', '', regex=True)

# If you want to remove # from all string entries in the entire DataFrame
df = df.replace('#', '', regex=True)
#df = df.replace('⏩', '', regex=True)

# Save the cleaned DataFrame back to a CSV file (optional)
df.to_csv('cleaned_file.csv', index=False)
# Out:
# C:\Users\Admin.DESKTOP-M4R2VLU\AppData\Local\Temp\ipykernel_6624\1507921976.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Message'] = df['Message'].replace('#', '', regex=True)

# %%
df
# Out:
#                                          Channel Title Channel Username    ID  \
# 0    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2399
# 2    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2396
# 3    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2395
# 5    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2393
# 6    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2392
# ..                                                 ...              ...   ...
# 845  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1457
# 846  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1456
# 847  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1455
# 849  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1453
# 850  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1452
#
# ...

# %%
# Out:
# Channel Title        0
# Channel Username     0
# ID                   0
# Message              0
# Date                 0
# Media Path          57
# dtype: int64

# %%
df.to_csv(r'C:\Users\Admin.DESKTOP-M4R2VLU\week7\data\clean_EAHCI.csv')
